# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ---------------
# anyio                     4.12.1
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# astroid                   4.0.3
# asttokens                 3.0.1
# async-lru                 2.1.0
# attrs                     23.2.0
# Automat                   22.10.0
# autopep8                  2.0.4
# Babel                     2.10.3
# bcc                       0.29.1
# bcrypt                    3.2.2
# beautifulsoup4            4.14.3
# black                     26.1.0
# bleach                    6.3.0
# blinker                   1.7.0
# boto3                     1.34.46
# botocore                  1.34.46
# certifi                   2023.11.17
# cffi                      2.0.0
# chardet                   5.2.0
# click                     8.1.6
# cloud-init                25.2
# colorama                  0.4.6
# comm                      0.2.3
# ...
